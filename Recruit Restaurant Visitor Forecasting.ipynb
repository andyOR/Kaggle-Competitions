# %%
cd C:\2017\Work\Python\Kaggle\RRVF
# Out:
# C:\2017\Work\Python\Kaggle\RRVF

# %%
import pandas as pd
air_vis_data = pd.read_csv('air_visit_data.csv')
air_vis_data.info()
air_vis_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252108 entries, 0 to 252107
# Data columns (total 3 columns):
# air_store_id    252108 non-null object
# visit_date      252108 non-null object
# visitors        252108 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 5.8+ MB
#             visitors
# count  252108.000000
# mean       20.973761
# std        16.757007
# min         1.000000
# 25%         9.000000
# 50%        17.000000
# 75%        29.000000
# max       877.000000

# %% [markdown]
# Air visit data has three columns with store id, visitation date and number of visitors on each date. There are 252108 observation and no missing values. The highest and lowest value in each columns are (477,20), (799, 48) and (8685, 1).

# %%
air_vis_data['visitors'].value_counts()

# %%
air_vis_data.head(20)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
x = air_vis_data['visitors']
n, bins, patches = plt.hist(x, 50, facecolor='green', alpha=0.8)
plt.xlabel("Per day visitors") # xlabel added
plt.ylabel("Frequency")# ylabel added
plt.title("Distribution of Air restaurants visitors") # added title
plt.show()

# %%
air_res_data = pd.read_csv('air_reserve.csv')
air_res_data.info()
air_res_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92378 entries, 0 to 92377
# Data columns (total 4 columns):
# air_store_id        92378 non-null object
# visit_datetime      92378 non-null object
# reserve_datetime    92378 non-null object
# reserve_visitors    92378 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 2.8+ MB
#        reserve_visitors
# count      92378.000000
# mean           4.481749
# std            4.919669
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            5.000000
# max          100.000000

# %% [markdown]
# Air reserve dataset contains 4 columns and 92378 observations with no missing values.  Three are three objective columns of store id, vistation date and date of reservation and fourth one is interger column for number of visitors. The highest, lowest and unique values in each columns are (2263,1, 314), (255, 4975),  and (106, 1, 7513) and (38622, 1, 71).

# %%
air_res_data['reserve_datetime'].value_counts()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(2,1,1)
ax1.hist(air_vis_data['visitors'],bins=50)
ax1.set_title("Distribution of values for past air restaurant visitors", color='blue')
ax1.set_ylabel("Frequency")
ax1.set_xlabel("visitors count")
ax2 = fig.add_subplot(2,1,2)
ax2.hist(air_res_data['reserve_visitors'],bins=50)
ax2.set_title("Distribution of visitor values in air reservation systems", color='blue')
ax2.set_ylabel("Frequency")
ax2.set_xlabel("visitors count")
plt.show()

# %%
hpg_res_data = pd.read_csv('hpg_reserve.csv')
hpg_res_data.info()
hpg_res_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000320 entries, 0 to 2000319
# Data columns (total 4 columns):
# hpg_store_id        object
# visit_datetime      object
# reserve_datetime    object
# reserve_visitors    int64
# dtypes: int64(1), object(3)
# memory usage: 61.0+ MB
#        reserve_visitors
# count      2.000320e+06
# mean       5.073785e+00
# std        5.416172e+00
# min        1.000000e+00
# 25%        2.000000e+00
# 50%        3.000000e+00
# 75%        6.000000e+00
# max        1.000000e+02

# %% [markdown]
# hpg reserve contains 4 columns with over 2 million observations with no missing values. It displays same knd of
# information as air reserve data from hpg database. The highest, lowest and unique values in each columns are (1155,1, 13325), (10528, 1, 9847),  and (907, 1, 11450) and (697937, 1, 99).

# %%
hpg_res_data.isnull().sum()
# Out:
# hpg_store_id        0
# visit_datetime      0
# reserve_datetime    0
# reserve_visitors    0
# dtype: int64

# %%
hpg_res_data['reserve_visitors'].value_counts()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
x = hpg_res_data['reserve_visitors']
n, bins, patches = plt.hist(x, 50, facecolor='green', alpha=0.8)
plt.xlabel("Per day visitors") # xlabel added
plt.ylabel("Frequency")# ylabel added
plt.title("Distribution of visitor values in hpg reservation systems") # added title
plt.show()

# %%
air_str_data = pd.read_csv('air_store_info.csv')
air_str_data.info()
air_str_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 5 columns):
# air_store_id      829 non-null object
# air_genre_name    829 non-null object
# air_area_name     829 non-null object
# latitude          829 non-null float64
# longitude         829 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 32.5+ KB
#          latitude   longitude
# count  829.000000  829.000000
# mean    35.647042  137.415311
# std      2.084659    3.650971
# min     33.211967  130.195555
# 25%     34.695124  135.341564
# 50%     35.658068  139.685474
# 75%     35.694003  139.751599
# max     44.020632  144.273398

# %% [markdown]
# Air store info dataset contains 5 columns and 829 rows with no missing values. It contains store id, type of restaurant
# (cuisine type), area name in which restaurant is located and location co-ordiantes of the restaurant. The highest, lowest and unique values in each columns are (1,1, 829), (197, 2, 14), (,64 2, 103), (62, 2, 108) and (62, 2, 108).

# %%
air_str_data['latitude'].value_counts()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = air_str_data['air_genre_name'].unique()
y_pos = np.arange(len(objects))
performance = air_str_data['air_genre_name'].value_counts()
 
plt.bar(y_pos, performance, align='center', alpha=0.7)
plt.xticks(y_pos, objects, rotation = 90)
plt.ylabel('Number of restaurants')
plt.title('Different type of Area Genre restaurants ')
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = air_str_data['air_genre_name'].unique()
y_pos = np.arange(len(objects))
performance = air_str_data['air_genre_name'].value_counts()
 
plt.barh(y_pos, performance, align='center', alpha=0.7)
plt.yticks(y_pos, objects)
plt.xlabel('Number of restaurants')
plt.title('Different type of Area Genre restaurants ')
 
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

m = Basemap(projection= "merc", llcrnrlat= 30, urcrnrlat= 50, llcrnrlon= 120, urcrnrlon= 160)
longitudes = air_str_data["longitude"].tolist()
latitudes = air_str_data["latitude"].tolist()
x, y = m(longitudes, latitudes)
m.scatter(x,y, s =1) # scatter plot with marker size of 1
m.drawcoastlines()
plt.show()

# %%
hpg_str_data = pd.read_csv('hpg_store_info.csv')
hpg_str_data.info()
hpg_str_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4690 entries, 0 to 4689
# Data columns (total 5 columns):
# hpg_store_id      4690 non-null object
# hpg_genre_name    4690 non-null object
# hpg_area_name     4690 non-null object
# latitude          4690 non-null float64
# longitude         4690 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 183.3+ KB
#           latitude    longitude
# count  4690.000000  4690.000000
# mean     35.810261   137.675816
# std       2.138755     3.197233
# min      33.311645   130.339313
# 25%      34.692109   135.498859
# 50%      35.659214   139.495733
# 75%      35.703381   139.737998
# max      43.774846   143.714585

# %% [markdown]
# The hpg store data contains 5 columns and 4690 rows with no missing values. It contains same kind of information as
# the air store dataset. The highest, lowest and unique values in each columns are (1,1,4690), (1750,1,34), (257,1,119), (257, 1, 129) and (257, 1, 129).

# %%
hpg_str_data['hpg_area_name'].value_counts()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
 
objects = hpg_str_data['hpg_genre_name'].unique()
y_pos = -np.arange(len(objects))
performance = hpg_str_data['hpg_genre_name'].value_counts()
 
plt.barh(y_pos, performance, align='center', alpha=0.7)
plt.yticks(y_pos, objects)
plt.xlabel('Number of restaurants')
plt.title('Different type of Area Genre restaurants in HPG system')
 
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

m = Basemap(projection= "merc", llcrnrlat= 30, urcrnrlat= 50, llcrnrlon= 120, urcrnrlon= 160)
longitudes = hpg_str_data["longitude"].tolist()
latitudes = hpg_str_data["latitude"].tolist()
x, y = m(longitudes, latitudes)
m.scatter(x,y, s =1) # scatter plot with marker size of 1
m.drawcoastlines()
plt.show()

# %%
date_info = pd.read_csv('date_info.csv')
date_info.info()
date_info.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
# calendar_date    517 non-null object
# day_of_week      517 non-null object
# holiday_flg      517 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 12.2+ KB
#        holiday_flg
# count   517.000000
# mean      0.067698
# std       0.251471
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
date_info.head(10)
# Out:
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-01      Friday            1
# 1    2016-01-02    Saturday            1
# 2    2016-01-03      Sunday            1
# 3    2016-01-04      Monday            0
# 4    2016-01-05     Tuesday            0
# 5    2016-01-06   Wednesday            0
# 6    2016-01-07    Thursday            0
# 7    2016-01-08      Friday            0
# 8    2016-01-09    Saturday            0
# 9    2016-01-10      Sunday            0

# %% [markdown]
# The date info dataset contains 3 columns and 517 rows with no missing values. It contains date, day of the week and if
# holiday arrives on this date.

# %%
date_info['day_of_week'].value_counts()
# Out:
# Saturday     74
# Wednesday    74
# Sunday       74
# Friday       74
# Tuesday      74
# Monday       74
# Thursday     73
# Name: day_of_week, dtype: int64

# %%
holi_sum = date_info.pivot_table(index= 'day_of_week', values = 'holiday_flg',aggfunc=np.sum)

# %%
holi_sum.values
# Out:
# array([[5],
#        [9],
#        [5],
#        [4],
#        [7],
#        [2],
#        [3]], dtype=int64)

# %%
objects = date_info['day_of_week'].unique()
y_pos = np.arange(len(objects))
holi_sum = date_info.pivot_table(index= 'day_of_week', values = 'holiday_flg',aggfunc=np.sum)
values = sorted(holi_sum.values)
 
plt.barh(y_pos, values, align='center', alpha=0.7, color='green')
plt.yticks(y_pos, objects)
plt.xlabel('Holiday frequency')
plt.title('Number of the holidays on days of the week')
 
plt.show()

# %%
store_relatn = pd.read_csv('store_id_relation.csv')
store_relatn.info()
store_relatn.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
# air_store_id    150 non-null object
# hpg_store_id    150 non-null object
# dtypes: object(2)
# memory usage: 2.4+ KB
#                 air_store_id          hpg_store_id
# count                    150                   150
# unique                   150                   150
# top     air_640cf4835f0d9ba3  hpg_8d472b917afb2cd9
# freq                       1                     1

# %% [markdown]
# The store relation dataset contains 2 columns with 150 columns with no missing values. It contains the connection of
# air store id with hpg id.

# %%
test_str_data = pd.read_csv('sample_submission.csv')
test_str_data.info()
test_str_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32019 entries, 0 to 32018
# Data columns (total 2 columns):
# id          32019 non-null object
# visitors    32019 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 500.4+ KB
#        visitors
# count   32019.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
Sample submission dataset contain 2 columns and 32019 rows. This is the test file for the kaggle submission.
